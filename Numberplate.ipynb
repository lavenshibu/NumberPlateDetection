# %% [markdown]
# <a href="https://colab.research.google.com/github/lavenshibu/NumberPlateDetection/blob/main/Numberplate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ROOT_DIR = '/content/gdrive/My Drive/yolo4'

# %%
# !pip install ultralytics

# %%
import os
from ultralytics import YOLO
# Load a model
model = YOLO("yolov8n.pt")
# build a new model from scratch # Use the model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=80)
# Out:
# Ultralytics 8.3.252 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/yolo4'
# Out:
# cp: cannot stat '/content/runs': No such file or directory

# %%
from ultralytics import YOLO

# Load the trained model (replace with the correct path to your model weights)
model = YOLO(f'{ROOT_DIR}/runs/detect/train2/weights/best.pt')

# %%
# Define the path to the test images
test_image_dir = f'{ROOT_DIR}/test/images/'

# Run inference on the test dataset
results = model.predict(source=test_image_dir, imgsz=640, conf=0.25)

# Display the results (images with bounding boxes)
for result in results:
    result.show()  # This will show each result individually

# %%
# !ls "/content/gdrive/My Drive/yolo1/labels/val"
# Out:
# ls: cannot access '/content/gdrive/My Drive/yolo1/labels/val': No such file or directory
